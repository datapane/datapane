# %% [markdown]
# # Controls catalog
#
# Welcome to the Datapane controls catalog. Here you will find functioning and reusable examples of Datapane controls in action.

# %% [markdown]
# ## Inputs
#
# Add input controls to your apps, from text entry to date pickers.
#
# <div class="grid cards" markdown>
#
# -   __[TextBox](/catalogs/controls/textbox)__
#
#     <a href="/catalogs/controls/textbox"><img style="width:100%;" src="../../img/catalogs/textbox.png"></a>
#
# -   __[Switch](/catalogs/controls/switch)__
#
#     <a href="/catalogs/controls/switch"><img style="width:100%;" src="../../img/catalogs/switch.png"></a>
#
# -   __[Range](/catalogs/controls/range)__
#
#     <a href="/catalogs/controls/range"><img style="width:100%;" src="../../img/catalogs/range.png"></a>
#
# -   __[Choice](/catalogs/controls/choice)__
#
#     <a href="/catalogs/controls/choice"><img style="width:100%;" src="../../img/catalogs/choice.png"></a>
#
# -   __[MultiChoice](/catalogs/controls/multichoice)__
#
#     <a href="/catalogs/controls/multichoice"><img style="width:100%;" src="../../img/catalogs/multichoice.png"></a>
#
# -   __[Tags](/catalogs/controls/tags)__
#
#     <a href="/catalogs/controls/tags"><img style="width:100%;" src="../../img/catalogs/tags.png"></a>
#
# -   __[Date](/catalogs/controls/date)__
#
#     <a href="/catalogs/controls/date"><img style="width:100%;" src="../../img/catalogs/date.png"></a>
#
# -   __[Time](/catalogs/controls/time)__
#
#     <a href="/catalogs/controls/time"><img style="width:100%;" src="../../img/catalogs/time.png"></a>
#
# -   __[DateTime](/catalogs/controls/datetime)__
#
#     <a href="/catalogs/controls/datetime"><img style="width:100%;" src="../../img/catalogs/datetime.png"></a>
#
# -   __[File](/catalogs/controls/file)__
#
#     <a href="/catalogs/controls/file"><img style="width:100%;" src="../../img/catalogs/file.png"></a>
#
# </div>

# %% [markdown]
# ## Targets
#
# <div class="grid cards" markdown>
#
# -   __[Block ID](/catalogs/controls/target/block-id)__
#
#     <a href="/catalogs/controls/target/block-id"><img style="width:100%;" src="../../img/catalogs/block-id.png"></a>
#
# -   __[Self](/catalogs/controls/target/self)__
#
#     <a href="/catalogs/controls/target/self"><img style="width:100%;" src="../../img/catalogs/self.png"></a>
#
# -   __[Side](/catalogs/controls/target/side)__
#
#     <a href="/catalogs/controls/target/side"><img style="width:100%;" src="../../img/catalogs/side.png"></a>
#
# -   __[Below](/catalogs/controls/target/below)__
#
#     <a href="/catalogs/controls/target/below"><img style="width:100%;" src="../../img/catalogs/below.png"></a>
#
# </div>
#
#
# ## Swapping
#
# <div class="grid cards" markdown>
#
# -   __[Replace](/catalogs/controls/swap/replace)__
#
#     <a href="/catalogs/controls/swap/replace"><img style="width:100%;" src="../../img/catalogs/replace.png"></a>
#
# -   __[Inner](/catalogs/controls/swap/inner)__
#
#     <a href="/catalogs/controls/swap/inner"><img style="width:100%;" src="../../img/catalogs/inner.png"></a>
#
# -   __[Prepend](/catalogs/controls/swap/prepend)__
#
#     <a href="/catalogs/controls/swap/prepend"><img style="width:100%;" src="../../img/catalogs/prepend.png"></a>
#
# -   __[Append](/catalogs/controls/append/replace)__
#
#     <a href="/catalogs/controls/swap/append"><img style="width:100%;" src="../../img/catalogs/append.png"></a>
#
# </div>
